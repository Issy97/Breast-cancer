# %%
#import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data= pd.read_csv("C:\\Users\\debbi\\Downloads\\breast-cancer.csv")
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
correlation= data.corr(numeric_only=True)
print (correlation)
# Out:
#                                id  radius_mean  texture_mean  perimeter_mean  \
# id                       1.000000     0.074626      0.099770        0.073159
# radius_mean              0.074626     1.000000      0.323782        0.997855
# texture_mean             0.099770     0.323782      1.000000        0.329533
# perimeter_mean           0.073159     0.997855      0.329533        1.000000
# area_mean                0.096893     0.987357      0.321086        0.986507
# smoothness_mean         -0.012968     0.170581     -0.023389        0.207278
# compactness_mean         0.000096     0.506124      0.236702        0.556936
# concavity_mean           0.050080     0.676764      0.302418        0.716136
# concave points_mean      0.044158     0.822529      0.293464        0.850977
# symmetry_mean           -0.022114     0.147741      0.071401        0.183027
# fractal_dimension_mean  -0.052511    -0.311631     -0.076437       -0.261477
# ...

# %%
correlation = data.select_dtypes(include=[np.number]).corr()
print (correlation)
# Out:
#                                id  radius_mean  texture_mean  perimeter_mean  \
# id                       1.000000     0.074626      0.099770        0.073159
# radius_mean              0.074626     1.000000      0.323782        0.997855
# texture_mean             0.099770     0.323782      1.000000        0.329533
# perimeter_mean           0.073159     0.997855      0.329533        1.000000
# area_mean                0.096893     0.987357      0.321086        0.986507
# smoothness_mean         -0.012968     0.170581     -0.023389        0.207278
# compactness_mean         0.000096     0.506124      0.236702        0.556936
# concavity_mean           0.050080     0.676764      0.302418        0.716136
# concave points_mean      0.044158     0.822529      0.293464        0.850977
# symmetry_mean           -0.022114     0.147741      0.071401        0.183027
# fractal_dimension_mean  -0.052511    -0.311631     -0.076437       -0.261477
# ...

# %%
plt.figure(figsize=(10, 8))

# %%
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.3f', linewidths=0.8)
# Out:
# <Axes: >

# %%
plt.title('Correlation Matrix Heatmap')
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.tight_layout()

# %%
plt.show()

# %%
from sklearn.model_selection import train_test_split

x = data.drop("diagnosis", axis=1)
y = data['diagnosis']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
model = LogisticRegression ()
model.fit (x_train, y_train)
# Out:
# LogisticRegression()

# %%
prediction= model.predict(x_test)
print(prediction)
# Out:
# ['B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B']

# %%
accuracy= accuracy_score(prediction,y_test)
print(accuracy)
# Out:
# 0.5877192982456141

# %%
mean_values = data[['radius_mean', 'texture_mean', 'perimeter_mean']].mean()

print("Mean values:")
print(mean_values)
# Out:
# Mean values:
# radius_mean       14.127292
# texture_mean      19.289649
# perimeter_mean    91.969033
# dtype: float64

# %%
median_values = data[['radius_mean', 'texture_mean', 'perimeter_mean']].median()

print("\nMedian values:")
print(median_values)
# Out:
# Median values:
# radius_mean       13.37
# texture_mean      18.84
# perimeter_mean    86.24
# dtype: float64

# %%
mode_values = data[['radius_mean', 'texture_mean', 'perimeter_mean']].mode()

print("\nMode values:")
print(mode_values)
# Out:
# Mode values:
#    radius_mean  texture_mean  perimeter_mean
# 0        12.34         14.93           82.61
# 1          NaN         15.70           87.76
# 2          NaN         16.84          134.70
# 3          NaN         16.85             NaN
# 4          NaN         17.46             NaN
# 5          NaN         18.22             NaN
# 6          NaN         18.90             NaN
# 7          NaN         19.83             NaN
# 8          NaN         20.52             NaN
